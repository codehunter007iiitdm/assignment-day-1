# %% [markdown]
# <a href="https://colab.research.google.com/github/codehunter007iiitdm/assignment-day-1/blob/main/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=input('enter the values: ')
y=[int(i) for i in x.split()]
y.sort()
y.reverse()
print(y)
